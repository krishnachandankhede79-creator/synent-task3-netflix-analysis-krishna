# %% [markdown]
# Imported pandas Library

# %%
import pandas as pd

# %% [markdown]
# Loaded the Netflix Dataset

# %%
df=pd.read_csv('NetFlix.csv')
df.head()
# Out:
#   show_id     type                                      title        director  \
# 0      s1  TV Show                                         3%             NaN
# 1     s10    Movie                                       1920    Vikram Bhatt
# 2    s100    Movie                                 3 Heroines  Iman Brotoseno
# 3   s1000    Movie  Blue Mountain State: The Rise of Thadland    Lev L. Spiro
# 4   s1001  TV Show                             Blue Planet II             NaN
#
#                                                 cast         country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...          Brazil
# 1  Rajneesh Duggal, Adah Sharma, Indraneil Sengup...           India
# 2  Reza Rahadian, Bunga Citra Lestari, Tara Basro...       Indonesia
# 3  Alan Ritchson, Darin Brooks, James Cade, Rob R...   United States
# 4                                 David Attenborough  United Kingdom
#
#   date_added  release_year rating  duration  \
# 0  14-Aug-20          2020  TV-MA         4
# 1  15-Dec-17          2008  TV-MA       143
# 2   5-Jan-19          2016  TV-PG       124
# 3   1-Mar-16          2016      R        90
# 4   3-Dec-18          2017   TV-G         1
#
#                                               genres  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1     Horror Movies, International Movies, Thrillers
# 2        Dramas, International Movies, Sports Movies
# 3                                           Comedies
# 4  British TV Shows, Docuseries, Science & Nature TV
#
#                                          description
# 0  In a future where the elite inhabit an island ...
# 1  An architect and his wife move into a castle t...
# 2  Three Indonesian women break records by becomi...
# 3  New NFL star Thad buys his old teammates' belo...
# 4  This sequel to the award-winning nature series...

# %% [markdown]
# Checked columns in dataset

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'genres', 'description'],
#       dtype='object')

# %% [markdown]
# Performed Statistical analysis

# %%
df.describe()
# Out:
#        release_year     duration
# count   7787.000000  7787.000000
# mean    2013.932580    69.122769
# std        8.757395    50.950743
# min     1925.000000     1.000000
# 25%     2013.000000     2.000000
# 50%     2017.000000    88.000000
# 75%     2018.000000   106.000000
# max     2021.000000   312.000000

# %% [markdown]
# Mean

# %%
df.mean(numeric_only=True)
# Out:
# release_year    2013.932580
# duration          69.122769
# dtype: float64

# %% [markdown]
# Median

# %%
df.median(numeric_only=True)
# Out:
# release_year    2017.0
# duration          88.0
# dtype: float64

# %% [markdown]
# Mode

# %%
df.mode()
# Out:
#      show_id   type                          title                director  \
# 0         s1  Movie                         #Alive  Raúl Campos, Jan Suter
# 1        s10    NaN  #AnneFrank - Parallel Stories                     NaN
# 2       s100    NaN              #FriendButMarried                     NaN
# 3      s1000    NaN            #FriendButMarried 2                     NaN
# 4      s1001    NaN                          #Roxy                     NaN
# ...      ...    ...                            ...                     ...
# 7782    s995    NaN                       忍者ハットリくん                     NaN
# 7783    s996    NaN                           海的儿子                     NaN
# 7784    s997    NaN                           마녀사냥                     NaN
# 7785    s998    NaN                        반드시 잡는다                     NaN
# 7786    s999    NaN            최강전사 미니특공대 : 영웅의 탄생                     NaN
#
#                     cast        country date_added  release_year rating  \
# 0     David Attenborough  United States   1-Jan-20        2018.0  TV-MA
# 1                    NaN            NaN        NaN           NaN    NaN
# 2                    NaN            NaN        NaN           NaN    NaN
# 3                    NaN            NaN        NaN           NaN    NaN
# 4                    NaN            NaN        NaN           NaN    NaN
# ...                  ...            ...        ...           ...    ...
# 7782                 NaN            NaN        NaN           NaN    NaN
# 7783                 NaN            NaN        NaN           NaN    NaN
# 7784                 NaN            NaN        NaN           NaN    NaN
# 7785                 NaN            NaN        NaN           NaN    NaN
# 7786                 NaN            NaN        NaN           NaN    NaN
#
#       duration         genres  \
# 0          1.0  Documentaries
# 1          NaN            NaN
# 2          NaN            NaN
# 3          NaN            NaN
# 4          NaN            NaN
# ...        ...            ...
# 7782       NaN            NaN
# 7783       NaN            NaN
# 7784       NaN            NaN
# 7785       NaN            NaN
# 7786       NaN            NaN
#
#                                             description
# 0     A surly septuagenarian gets another chance at ...
# 1     Multiple women report their husbands as missin...
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 7782                                                NaN
# 7783                                                NaN
# 7784                                                NaN
# 7785                                                NaN
# 7786                                                NaN
#
# [7787 rows x 12 columns]

# %% [markdown]
# Standard Deviation

# %%
df.std(numeric_only=True)
# Out:
# release_year     8.757395
# duration        50.950743
# dtype: float64

# %% [markdown]
# Variance

# %%
df.var(numeric_only=True)
# Out:
# release_year      76.691961
# duration        2595.978247
# dtype: float64
